# %% [markdown]
# ### Without any selection (baseline)

# %%
import sys
sys.path.append('../code/')
import regression_per_task

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         n_pca_var=None,
                         n_pca_cor=None,
                         variance_features=None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.16517374 -0.24779319 -0.66985568  0.17158952  0.22194212]
# [ 0.06762627 -0.42359219 -0.46188992  0.05211842  0.22283083]
# [-0.11008476 -0.03284695 -0.61799357 -0.00080551  0.21708178]
# [ 0.22714771  0.17192531 -0.5062358  -0.06387841  0.29410252]
# [-0.10381083 -0.3677572  -0.90546787  0.10462678 -0.09250403]
# [ 0.31859069 -0.39716332 -0.93057708 -0.05895929  0.04184386]
#
#
#
# ['Rand_F' 'SVM' 'Bayes_R' 'Gauss_P' 'ANN']
# ['Gauss_P' 'SVM' 'Gauss_P' 'KNN' 'Rand_F']
# ['Bayes_R' 'SVM' 'Gauss_P' 'Gauss_P' 'Gauss_P']
# ['Rand_F' 'SVM' 'SVM' 'Bayes_R' 'ANN']
# ['Bayes_R' 'KNN' 'Gauss_P' 'Rand_F' 'Gauss_P']
# ['Gauss_P' 'Gauss_P' 'Bayes_R' 'Bayes_R' 'SVM']

# %% [markdown]
# ### With PCA
# * after variance and correlation selection

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=10,
                         n_pca_cor=10,
                         variance_features = None)
# Out:
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.29801705 -0.3433859  -0.61468056  0.41863283  0.12958743]
# [-0.10667806  0.3418483  -0.77859296 -0.06257488 -0.00709469]
# [-0.08546536 -0.31624768 -0.24317071  0.30001466  0.35562797]
# [ 0.37735972 -0.04973164 -0.2716198  -0.06257222  0.12952776]
# [-0.10387841 -0.56726106 -0.68595035  0.13386182 -0.15901868]
# [ 0.46313196 -0.01618817 -0.62340552  0.04422925  0.17973778]
#
#
#
# ['KNN' 'Bayes_R' 'KNN' 'SVM' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R' 'Gauss_P']
# ['KNN' 'Bayes_R' 'ANN' 'KNN' 'ANN']
# ['Rand_F' 'ANN' 'KNN' 'Bayes_R' 'SVM']
# ['Bayes_R' 'KNN' 'KNN' 'KNN' 'Bayes_R']
# ...

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=5,
                         n_pca_cor=5,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.05519511 -0.32000836 -0.63756764  0.04035559  0.11200544]
# [ 0.01380598 -0.46784055 -0.45106012 -0.00577398  0.07328665]
# [-0.10861538 -0.26455656 -0.78088422  0.25573362  0.35159158]
# [ 0.4055999   0.25944183 -0.10602021 -0.06146577  0.47683364]
# [-0.10407361 -0.48634307 -0.79141006  0.21724528 -0.29858234]
# [ 0.08639686 -0.9159975  -0.71491919 -0.05915415 -0.00898773]
#
#
#
# ['ANN' 'KNN' 'KNN' 'KNN' 'Bayes_R']
# ['KNN' 'Bayes_R' 'ANN' 'KNN' 'ANN']
# ['Bayes_R' 'ANN' 'Bayes_R' 'Bayes_R' 'ANN']
# ['Rand_F' 'Rand_F' 'Lin_Reg' 'Bayes_R' 'ANN']
# ['Bayes_R' 'ANN' 'Bayes_R' 'ANN' 'Lin_Reg']
# ['Rand_F' 'KNN' 'ANN' 'Bayes_R' 'ANN']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=12,
                         n_pca_cor=12,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ -1.10677096e-01  -4.55205504e-04  -6.26424321e-01   4.29246423e-01
#    1.41958363e-01]
# [-0.10670419 -0.44950669 -0.61537    -0.05429428  0.03952528]
# [-0.10895412 -0.16663262 -0.33934563  0.21933469  0.29959072]
# [ 0.22398634  0.03717138 -0.02711438 -0.06254293  0.1407018 ]
# [-0.10401422 -0.27632018 -0.65630867  0.25641321 -0.20578075]
# [ 0.61650534 -0.15475146 -0.54550484 -0.05905679  0.12622129]
#
#
#
# ['Bayes_R' 'KNN' 'Rand_F' 'SVM' 'ANN']
# ['Bayes_R' 'Bayes_R' 'ANN' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'SVM' 'Bayes_R' 'Gauss_P']
# ['Rand_F' 'KNN' 'KNN' 'Bayes_R' 'ANN']
# ['Bayes_R' 'KNN' 'ANN' 'KNN' 'Bayes_R']
# ['Rand_F' 'ANN' 'ANN' 'Bayes_R' 'KNN']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=4,
                         n_pca_cor=3,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.13620306 -0.34505047 -0.49886607  0.08116433  0.16459125]
# [-0.09615157 -0.39642027 -0.7783515  -0.05990489  0.08559269]
# [-0.10858921  0.30700055 -0.69987602  0.17321517  0.40953368]
# [ 0.53552907 -0.02400772  0.03129674 -0.06242933  0.0740303 ]
# [ 0.11850167 -0.51146339  0.11102804  0.17013102 -0.13248437]
# [-0.10178756 -0.70895788 -0.80305022 -0.05928166  0.08522567]
#
#
#
# ['KNN' 'Bayes_R' 'KNN' 'Bayes_R' 'Lin_Reg']
# ['KNN' 'KNN' 'Bayes_R' 'KNN' 'KNN']
# ['Bayes_R' 'ANN' 'KNN' 'Bayes_R' 'Gauss_P']
# ['Rand_F' 'Rand_F' 'Lin_Reg' 'Bayes_R' 'KNN']
# ['KNN' 'Bayes_R' 'Gauss_P' 'KNN' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R' 'KNN']

# %% [markdown]
# ### Only top n variance features

# %% [markdown]
# ##### n=10

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False, 
                         variance_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.11044447 -0.23878691 -0.43710721  0.17906648  0.11033472]
# [-0.10591134 -0.49097683 -0.72950266 -0.06172525  0.30041952]
# [ 0.24142532 -0.32814039  0.57878728  0.20656679  0.28529658]
# [ 0.47637076  0.15309612 -0.44696833  0.13493831  0.31025902]
# [-0.10416911 -0.49796869 -0.7916423  -0.05050985 -0.11447207]
# [ 0.41237198 -0.79252855 -0.33658167 -0.05904522  0.17517699]
#
#
#
# ['Bayes_R' 'ANN' 'Rand_F' 'SVM' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R' 'Gauss_P']
# ['ANN' 'Bayes_R' 'Gauss_P' 'Bayes_R' 'Lin_Reg']
# ['Rand_F' 'Rand_F' 'ANN' 'Lin_Reg' 'ANN']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'Bayes_R' 'Bayes_R']
# ['Rand_F' 'Rand_F' 'KNN' 'Bayes_R' 'Gauss_P']

# %% [markdown]
# #### n=5

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False, 
                         variance_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.13357202 -0.33011582 -0.56054474 -0.01195356  0.11261764]
# [-0.10623451 -0.4913324  -0.77813415 -0.06303728  0.29929647]
# [-0.10866788 -0.32916621 -0.22882056  0.17244055  0.26683251]
# [ 0.55527284  0.20486493  0.15039504 -0.06183822  0.1417657 ]
# [-0.10473514 -0.51578427 -0.0849933  -0.05016785  0.1070641 ]
# [ 0.00962253 -0.97506715 -0.35458784 -0.05943598  0.01364883]
#
#
#
# ['SVM' 'ANN' 'Rand_F' 'Lin_Reg' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'Bayes_R' 'ANN']
# ['Bayes_R' 'Bayes_R' 'SVM' 'Bayes_R' 'ANN']
# ['Rand_F' 'Rand_F' 'KNN' 'Bayes_R' 'Lin_Reg']
# ['Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R' 'ANN']
# ['Rand_F' 'Bayes_R' 'KNN' 'Bayes_R' 'SVM']

# %% [markdown]
# ### Only features with n highest correlation

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.22445403  0.26053198 -1.          0.58446756  0.14477797]
# [ 0.04822499 -0.06204214 -0.78080404  0.13314088 -0.21192013]
# [-0.22113589  0.00402813 -0.4106893  -0.0515115  -0.04740864]
# [-0.04193822 -0.16388743 -0.76162227  0.1297723   0.08565736]
# [ 0.00751852 -0.39727944 -0.33559123 -0.06256134  0.41096334]
# [-0.10024674 -0.34763959 -0.81524519  0.20122583  0.21098115]
#
#
#
# ['KNN' 'KNN' 'Nan' 'Rand_F' 'ANN']
# ['Bayes_R' 'SVM' 'Bayes_R' 'Lin_Reg' 'KNN']
# ['KNN' 'Lin_Reg' 'SVM' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Rand_F' 'SVM']
# ['KNN' 'Bayes_R' 'KNN' 'KNN' 'ANN']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'ANN' 'Rand_F']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.23992361  0.11097371 -1.          0.04081065  0.03167839]
# [ 0.34699845 -0.07229178 -0.68972396  0.01532547 -0.18769238]
# [-0.24028012 -0.05144233 -0.36239916 -0.01998802 -0.01731336]
# [-0.04702405 -0.05647803 -0.62110194  0.15141811  0.16208146]
# [ 0.08356734 -0.36642721 -0.71511818  0.00472881  0.0176608 ]
# [-0.10678685 -0.18536654 -0.83293711  0.05192495  0.39358486]
#
#
#
# ['ANN' 'KNN' 'Nan' 'Rand_F' 'Lin_Reg']
# ['Lin_Reg' 'KNN' 'Lin_Reg' 'Bayes_R' 'KNN']
# ['KNN' 'KNN' 'SVM' 'Rand_F' 'Rand_F']
# ['Bayes_R' 'KNN' 'SVM' 'ANN' 'SVM']
# ['KNN' 'Bayes_R' 'KNN' 'KNN' 'KNN']
# ['Bayes_R' 'KNN' 'Bayes_R' 'SVM' 'Rand_F']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=7)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.15656327  0.16293565 -0.71547784 -0.05077286  0.34006988]
# [ 0.23309028 -0.08721927 -0.55085841  0.15128695 -0.15344514]
# [-0.0041346  -0.0262885  -0.44839413 -0.05120718 -0.03743294]
# [-0.03951872 -0.30539276 -0.73520302  0.42092927  0.09945016]
# [-0.06835593 -0.38788148 -0.92211148 -0.03982502 -0.04685822]
# [-0.09212584 -0.27558856 -0.81746813  0.21707145  0.13256144]
#
#
#
# ['Rand_F' 'KNN' 'ANN' 'Bayes_R' 'Lin_Reg']
# ['Lin_Reg' 'SVM' 'Lin_Reg' 'Lin_Reg' 'KNN']
# ['KNN' 'KNN' 'SVM' 'KNN' 'Lin_Reg']
# ['Bayes_R' 'Lin_Reg' 'Bayes_R' 'ANN' 'Rand_F']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Lin_Reg' 'ANN']

# %% [markdown]
# ### Variance based and correlation based feature selection without PCA

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 10,
                         correlation_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.03238734 -0.33218657 -0.586523   -0.04909222  0.13250924]
# [-0.11388396 -0.49336794 -0.7396496  -0.07454736  0.34625969]
# [-0.03166191 -0.18670343 -0.07583893 -0.053259    0.1913636 ]
# [ 0.20597106  0.13051697 -0.66344758 -0.09435944  0.00830885]
# [-0.10824455 -0.55826361 -0.82275369 -0.0012849  -0.13522756]
# [-0.08059668 -0.00775454 -0.26273491 -0.07998873  0.26609635]
#
#
#
# ['KNN' 'Bayes_R' 'ANN' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'Lin_Reg' 'Bayes_R' 'ANN']
# ['KNN' 'Lin_Reg' 'KNN' 'Bayes_R' 'ANN']
# ['Rand_F' 'KNN' 'Lin_Reg' 'Bayes_R' 'ANN']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R']
# ['Lin_Reg' 'KNN' 'Rand_F' 'Bayes_R' 'SVM']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 5,
                         correlation_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.06336134 -0.10975091 -0.29510009  0.00343827  0.20203819]
# [-0.11107808 -0.45316962 -0.35601378 -0.03384874  0.21913105]
# [-0.11495675 -0.18670343 -0.41137556 -0.05264787  0.01687038]
# [ 0.20597106 -0.23317445 -0.66344758 -0.08572686 -0.04499888]
# [-0.10763396 -0.52827681 -0.48385852 -0.03123775  0.0051519 ]
# [-0.08059668 -0.30140104 -0.05393912  0.10084092  0.26609635]
#
#
#
# ['KNN' 'KNN' 'ANN' 'Lin_Reg' 'ANN']
# ['Bayes_R' 'KNN' 'KNN' 'KNN' 'ANN']
# ['KNN' 'Lin_Reg' 'KNN' 'Bayes_R' 'SVM']
# ['Rand_F' 'KNN' 'Lin_Reg' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'KNN' 'Lin_Reg' 'KNN']
# ['Lin_Reg' 'Bayes_R' 'KNN' 'KNN' 'SVM']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 3,
                         correlation_features=4)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.12276931 -0.34358306 -0.63107062  0.06481001  0.17951265]
# [-0.10995334 -0.17630277 -0.7396496  -0.06829978  0.15718351]
# [-0.11457967 -0.18670343 -0.49752577 -0.03279717  0.01687038]
# [ 0.20597106 -0.32886289 -0.66344758 -0.03672991  0.00524281]
# [-0.04708729 -0.35144095 -0.80563335 -0.03123775 -0.12960212]
# [-0.08059668 -0.27866039 -0.26273491 -0.07081654  0.26609635]
#
#
#
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'Lin_Reg' 'Lin_Reg']
# ['Bayes_R' 'KNN' 'Lin_Reg' 'Bayes_R' 'SVM']
# ['Bayes_R' 'Lin_Reg' 'SVM' 'KNN' 'SVM']
# ['Rand_F' 'Bayes_R' 'Lin_Reg' 'KNN' 'ANN']
# ['KNN' 'KNN' 'Bayes_R' 'Lin_Reg' 'Bayes_R']
# ['Lin_Reg' 'KNN' 'Rand_F' 'Bayes_R' 'SVM']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 12,
                         correlation_features=12)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.08739243 -0.33146402 -0.62279658 -0.03217045  0.1328029 ]
# [-0.11474757 -0.03980088 -0.76877253 -0.07563084  0.28114128]
# [-0.05667703  0.03195517 -0.44512816 -0.05344879  0.20777793]
# [ 0.20597106 -0.31995966 -0.66344758 -0.09930128  0.03974151]
# [-0.10839047 -0.28478461 -0.06166288 -0.03123775 -0.13676112]
# [-0.08059668 -0.30259297 -0.26273491 -0.08332448  0.26609635]
#
#
#
# ['KNN' 'Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R' 'ANN']
# ['KNN' 'KNN' 'ANN' 'Bayes_R' 'ANN']
# ['Rand_F' 'Bayes_R' 'Lin_Reg' 'Bayes_R' 'ANN']
# ['Bayes_R' 'KNN' 'KNN' 'Lin_Reg' 'Bayes_R']
# ['Lin_Reg' 'Bayes_R' 'Rand_F' 'Bayes_R' 'SVM']
