# %% [markdown]
# ### Without any selection (baseline)

# %%
import sys
sys.path.append('../code/')
import regression_per_task

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         n_pca_var=None,
                         n_pca_cor=None,
                         variance_features=None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.132423   -0.28470663 -0.37749107 -0.16578645 -0.10537281]
# [ 0.11770442 -0.36738474 -0.28313866 -0.54487766  0.32852999]
# [-0.0007385  -0.36754351 -0.30286619 -0.4254777   0.05311774]
# [-0.00282666  0.0959023  -0.15085781 -0.48789643  0.03125047]
# [ 0.08350069 -0.09237559 -0.44889456 -0.05043133  0.38914308]
# [-0.01647768 -0.17422839 -0.34641721  0.11182221  0.24347817]
#
#
#
# ['ANN' 'SVM' 'Bayes_R' 'KNN' 'Bayes_R']
# ['Rand_F' 'Bayes_R' 'Gauss_P' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'Gauss_P' 'KNN' 'KNN']
# ['SVM' 'SVM' 'ANN' 'KNN' 'ANN']
# ['SVM' 'SVM' 'Bayes_R' 'KNN' 'Rand_F']
# ['Bayes_R' 'Bayes_R' 'Gauss_P' 'ANN' 'ANN']

# %% [markdown]
# ### With PCA
# * after variance and correlation selection

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=10,
                         n_pca_cor=10,
                         variance_features = None)
# Out:
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.01634039  0.35375825 -0.37752603 -0.125      -0.31760782]
# [-0.00139526 -0.42517292 -0.37732279 -0.47560289  0.17831464]
# [-0.00127073 -0.21178755 -0.37972574 -0.31692923 -0.05967076]
# [ 0.1387368  -0.22500766 -0.33695619 -0.54377106  0.00396522]
# [ 0.01423859 -0.61394769 -0.25417534  0.15895062  0.09692074]
# [-0.01364724 -0.13091339 -0.3782351  -0.17509474  0.23134741]
#
#
#
# ['Bayes_R' 'Rand_F' 'Bayes_R' 'Rand_F' 'ANN']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'KNN' 'ANN']
# ['Bayes_R' 'KNN' 'Bayes_R' 'ANN' 'Rand_F']
# ['Gauss_P' 'KNN' 'KNN' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'Rand_F' 'Rand_F' 'Rand_F']
# ...

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=5,
                         n_pca_cor=5,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.00507082  0.1372562  -0.37750707 -0.22685185 -0.31515637]
# [-0.00128957 -0.14018158 -0.3773822  -0.5442156   0.36932153]
# [-0.00110652  0.31623202 -0.37533198 -0.35312394 -0.05083098]
# [ 0.15875085 -0.36853676 -0.37499076 -0.54304301  0.32155829]
# [ 0.06185374 -0.25963995 -0.35395172  0.07561728  0.16164055]
# [-0.01354398  0.06167766 -0.23893065 -0.55307335  0.35934899]
#
#
#
# ['KNN' 'Rand_F' 'Bayes_R' 'Rand_F' 'KNN']
# ['Bayes_R' 'Lin_Reg' 'Bayes_R' 'Bayes_R' 'KNN']
# ['Bayes_R' 'KNN' 'KNN' 'ANN' 'Rand_F']
# ['Gauss_P' 'Bayes_R' 'Bayes_R' 'Bayes_R' 'Lin_Reg']
# ['ANN' 'Bayes_R' 'Bayes_R' 'Rand_F' 'Rand_F']
# ['Bayes_R' 'Rand_F' 'SVM' 'Bayes_R' 'KNN']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=12,
                         n_pca_cor=12,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.01609215  0.30134249 -0.37774617 -0.13194444 -0.33229204]
# [-0.00142437 -0.28762134 -0.37726399 -0.54430639  0.27384012]
# [-0.00126055 -0.36536389 -0.33872654 -0.25603789 -0.03204645]
# [ 0.1449901   0.1897504  -0.37520157 -0.54384104  0.00393898]
# [ 0.01402771 -0.46661942 -0.20910913  0.13117284  0.04108157]
# [-0.01252063  0.04725124 -0.37819456 -0.43208721  0.15606609]
#
#
#
# ['Bayes_R' 'Rand_F' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R' 'KNN']
# ['Bayes_R' 'Bayes_R' 'Rand_F' 'Bayes_R' 'Rand_F']
# ['Gauss_P' 'Rand_F' 'Bayes_R' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Bayes_R' 'Lin_Reg' 'Rand_F' 'SVM']
# ['Bayes_R' 'SVM' 'Bayes_R' 'Gauss_P' 'KNN']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size=0.2,
                         print_extended=False,
                         pca=True,
                         n_pca_var=4,
                         n_pca_cor=3,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.01520201  0.26664824 -0.37761887 -0.50462963 -0.1220712 ]
# [-0.00117994 -0.08940793 -0.37738491 -0.54429747  0.08633102]
# [ 0.08037886 -0.24523285 -0.37962487 -0.53772847 -0.00087067]
# [ 0.14925898 -0.18699412 -0.16387345 -0.54389169  0.08202821]
# [ 0.01575324 -0.36955402 -0.35397412  0.40277778  0.09269027]
# [ 0.09712923  0.15667624 -0.01003555 -0.55107135  0.34930947]
#
#
#
# ['Bayes_R' 'Rand_F' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R' 'ANN']
# ['KNN' 'KNN' 'Bayes_R' 'ANN' 'Bayes_R']
# ['ANN' 'Rand_F' 'Lin_Reg' 'Bayes_R' 'KNN']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'Rand_F' 'Rand_F']
# ['KNN' 'KNN' 'Lin_Reg' 'Bayes_R' 'KNN']

# %% [markdown]
# ### Only top n variance features

# %% [markdown]
# ##### n=10

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False, 
                         variance_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.19574897 -0.39527699 -0.37714745 -0.35919983 -0.08409215]
# [ 0.25290446 -0.36809284 -0.37674253  0.04398086  0.00228559]
# [ 0.10264522 -0.36737591 -0.37977375  0.58695341  0.37323768]
# [-0.06933509 -0.36805405 -0.34284627 -0.5428713   0.20286485]
# [ 0.01701488 -0.24491046 -0.0045319   0.6051508   0.12706271]
# [ 0.30691221 -0.19979713 -0.22796997 -0.43906848  0.10608504]
#
#
#
# ['Lin_Reg' 'ANN' 'Bayes_R' 'ANN' 'Bayes_R']
# ['ANN' 'Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R']
# ['Lin_Reg' 'Bayes_R' 'Bayes_R' 'ANN' 'Rand_F']
# ['Bayes_R' 'Bayes_R' 'Lin_Reg' 'Bayes_R' 'Lin_Reg']
# ['Bayes_R' 'Lin_Reg' 'Rand_F' 'SVM' 'ANN']
# ['SVM' 'Bayes_R' 'Rand_F' 'SVM' 'Bayes_R']

# %% [markdown]
# #### n=5

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False, 
                         variance_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.01650565 -0.4106113  -0.37748237  0.0162037  -0.08283232]
# [ 0.37632949 -0.36790088 -0.29476157 -0.42772311  0.0609559 ]
# [ 0.05165133 -0.36704106 -0.37942595  0.02430771 -0.00040037]
# [-0.0492239  -0.26916815 -0.13803573 -0.54246378  0.14439314]
# [ 0.01702926 -0.36878492 -0.0067758   0.06635802  0.16821902]
# [ 0.10615431  0.34583683 -0.06573137  0.06116329  0.50001494]
#
#
#
# ['Bayes_R' 'ANN' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['SVM' 'Bayes_R' 'Lin_Reg' 'Lin_Reg' 'Bayes_R']
# ['Lin_Reg' 'Bayes_R' 'Bayes_R' 'ANN' 'Bayes_R']
# ['Rand_F' 'SVM' 'Lin_Reg' 'Bayes_R' 'Lin_Reg']
# ['Bayes_R' 'Bayes_R' 'ANN' 'Rand_F' 'Lin_Reg']
# ['Rand_F' 'ANN' 'Rand_F' 'SVM' 'Lin_Reg']

# %% [markdown]
# ### Only features with n highest correlation

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.05487497  0.00954083 -0.32151541 -0.16960551  0.14365939]
# [ 0.20307862 -0.11702608 -0.37807041 -0.54215498  0.44532735]
# [ 0.12421886  0.14873056 -0.50704677 -0.52664926  0.06095559]
# [-0.00187203 -0.16286054  0.17572653 -0.54294385  0.1572752 ]
# [ 0.33324042 -0.05371069 -0.46638544 -0.83989904  0.20710997]
# [ 0.08628522  0.22085681 -0.39135937  0.02790123  0.19019843]
#
#
#
# ['ANN' 'KNN' 'SVM' 'Lin_Reg' 'SVM']
# ['SVM' 'SVM' 'Bayes_R' 'Bayes_R' 'Lin_Reg']
# ['ANN' 'SVM' 'Lin_Reg' 'KNN' 'SVM']
# ['Bayes_R' 'KNN' 'ANN' 'Bayes_R' 'KNN']
# ['Lin_Reg' 'Lin_Reg' 'KNN' 'KNN' 'SVM']
# ['ANN' 'SVM' 'Bayes_R' 'Rand_F' 'Lin_Reg']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.510477   -0.09474507 -0.50354048 -0.54133153  0.28071016]
# [ 0.21665036 -0.05778066 -0.37844149 -0.64401912  0.17704121]
# [ 0.01434004 -0.05867364 -0.45403475 -0.30897259  0.0470542 ]
# [ 0.09511021 -0.2453382  -0.15540216 -0.47007125  0.2991522 ]
# [ 0.14988018 -0.01919813 -0.49545752 -0.21837916  0.16535912]
# [ 0.14026676  0.12017063 -0.39677873 -0.16147845 -0.00210888]
#
#
#
# ['Rand_F' 'SVM' 'Rand_F' 'Bayes_R' 'Lin_Reg']
# ['SVM' 'SVM' 'Bayes_R' 'Bayes_R' 'Lin_Reg']
# ['SVM' 'SVM' 'KNN' 'KNN' 'Lin_Reg']
# ['KNN' 'KNN' 'Lin_Reg' 'ANN' 'SVM']
# ['Lin_Reg' 'Lin_Reg' 'KNN' 'SVM' 'Rand_F']
# ['ANN' 'SVM' 'Bayes_R' 'SVM' 'Bayes_R']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=7)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.0361095  -0.07051264 -0.30735568 -0.54126452  0.17685343]
# [ 0.40683866 -0.11249376 -0.37852702 -0.46342563  0.16146255]
# [ 0.28917211  0.20449538 -0.50748502 -0.3565842   0.2289063 ]
# [ 0.08062867 -0.33208521 -0.19747437 -0.5396185   0.15895243]
# [ 0.21175752 -0.03706717 -0.42310103 -0.73724038  0.18239547]
# [ 0.23300373  0.38949125 -0.38631082  0.2666358   0.135     ]
#
#
#
# ['Rand_F' 'SVM' 'SVM' 'Bayes_R' 'Lin_Reg']
# ['ANN' 'SVM' 'Bayes_R' 'KNN' 'Lin_Reg']
# ['ANN' 'SVM' 'KNN' 'ANN' 'Rand_F']
# ['KNN' 'KNN' 'Lin_Reg' 'KNN' 'KNN']
# ['Lin_Reg' 'SVM' 'KNN' 'Bayes_R' 'SVM']
# ['ANN' 'SVM' 'Bayes_R' 'Rand_F' 'Rand_F']

# %% [markdown]
# ### Variance based and correlation based feature selection without PCA

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 10,
                         correlation_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.04453451 -0.04282483 -0.37348047 -0.13734568 -0.08546052]
# [ 0.31464307 -0.36159852 -0.04643066 -0.43277677  0.04104692]
# [  6.25514253e-04  -3.58962639e-01  -1.18202629e-01  -5.07404319e-01
#   -4.58193294e-04]
# [-0.08493068 -0.35172324 -0.33668287 -0.5475367   0.45659641]
# [ 0.0213091  -0.36898635 -0.32562091  0.35416667  0.01661863]
# [-0.03128264 -0.09319793 -0.16179173 -0.54783522  0.34049945]
#
#
#
# ['Lin_Reg' 'KNN' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['SVM' 'Bayes_R' 'KNN' 'ANN' 'KNN']
# ['Bayes_R' 'Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Lin_Reg' 'Lin_Reg' 'Bayes_R' 'SVM']
# ['Lin_Reg' 'Bayes_R' 'Rand_F' 'Rand_F' 'Lin_Reg']
# ['Bayes_R' 'Lin_Reg' 'KNN' 'Bayes_R' 'SVM']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 5,
                         correlation_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.0508027  -0.25699675 -0.3744137  -0.13734568 -0.08453979]
# [ 0.32202066 -0.28736071 -0.31033396 -0.52330168  0.29184955]
# [  1.33772793e-04  -2.96670442e-01  -1.06652839e-01  -5.07373447e-01
#   -4.40944724e-04]
# [-0.08473158 -0.35172324 -0.33668287 -0.54586065  0.45659641]
# [ 0.0213091  -0.36885343 -0.08195685  0.35416667  0.01661863]
# [ 0.00374531 -0.09319793 -0.04702074 -0.54743139  0.34049945]
#
#
#
# ['Lin_Reg' 'ANN' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['ANN' 'ANN' 'Lin_Reg' 'KNN' 'ANN']
# ['Bayes_R' 'KNN' 'KNN' 'Bayes_R' 'Bayes_R']
# ['Bayes_R' 'Lin_Reg' 'Lin_Reg' 'Bayes_R' 'SVM']
# ['Lin_Reg' 'Bayes_R' 'ANN' 'Rand_F' 'Lin_Reg']
# ['KNN' 'Lin_Reg' 'KNN' 'Bayes_R' 'SVM']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 3,
                         correlation_features=4)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.17195461 -0.40457301 -0.03233805 -0.13734568 -0.08425339]
# [ 0.31464307 -0.33513162 -0.35915845 -0.5488922   0.0409903 ]
# [ -9.60271197e-05  -3.15104386e-01  -2.56778803e-01  -3.01891144e-01
#   -4.29763865e-04]
# [-0.08467117 -0.07133105 -0.33668287 -0.54580505  0.45659641]
# [ 0.0213091  -0.36881141 -0.15202363  0.35416667  0.01661863]
# [-0.02249641  0.2658734   0.01432376 -0.54730679  0.34049945]
#
#
#
# ['Lin_Reg' 'Rand_F' 'KNN' 'Rand_F' 'Bayes_R']
# ['SVM' 'Lin_Reg' 'Lin_Reg' 'Bayes_R' 'Lin_Reg']
# ['Bayes_R' 'Lin_Reg' 'KNN' 'KNN' 'Bayes_R']
# ['Bayes_R' 'KNN' 'Lin_Reg' 'Bayes_R' 'SVM']
# ['Lin_Reg' 'Bayes_R' 'KNN' 'Rand_F' 'Lin_Reg']
# ['Bayes_R' 'KNN' 'ANN' 'Bayes_R' 'SVM']

# %%
regression_per_task.main(path_to_pickle='../pickle_data/feature_dataframes/all_features_per_task_w_sensor.p',
                         test_size = 0.2,
                         print_extended=False,
                         pca=False,
                         variance_features = 12,
                         correlation_features=12)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.02798987 -0.40457301 -0.37325    -0.13734568 -0.08581502]
# [ 0.31464307 -0.36102928 -0.32640091 -0.55405392  0.0676407 ]
# [ 0.0007574  -0.33631334 -0.02764731 -0.22438206 -0.00046215]
# [-0.08382629 -0.35172324 -0.33668287 -0.08994848  0.45659641]
# [ 0.0213091  -0.2909736  -0.13568567  0.35416667  0.01661863]
# [-0.03209028  0.23519316 -0.25402136 -0.54799204  0.34049945]
#
#
#
# ['Bayes_R' 'Rand_F' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['SVM' 'Bayes_R' 'Lin_Reg' 'Bayes_R' 'Lin_Reg']
# ['Bayes_R' 'KNN' 'KNN' 'KNN' 'Bayes_R']
# ['ANN' 'Lin_Reg' 'Lin_Reg' 'KNN' 'SVM']
# ['Lin_Reg' 'KNN' 'KNN' 'Rand_F' 'Lin_Reg']
# ['ANN' 'ANN' 'SVM' 'Bayes_R' 'SVM']
