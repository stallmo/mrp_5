# %%
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../code/")
from svm_ann import main

# %%
for seed in [1,28,42]:
    predictions = main("../pickle_data/feature_dataframes/all_features_restructured.p", seed, True)
    sns.heatmap(predictions, annot=True)
    plt.title("Estimator accuracies per trait per task using random seed: {}".format(seed))
    plt.show()
# Out:
# Prediction: [0 0 1 1 1 0 1]
# Actual:  [0 1 1 0 0 0 1]
# Prediction: [0 0 1 0 0 0 0]
# Actual:  [0 0 0 0 0 1 1]
# Prediction: [1 1 1 0 1 0 0]
# Actual:  [1 1 1 0 0 0 0]
# Prediction: [1 0 0 0 0 0 0]
# Actual:  [1 1 0 1 1 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 1 1 1 0 1 0]
# Prediction: [1 0 0 1 1 1 1]
# Actual:  [0 1 1 0 0 0 1]
# Prediction: [1 1 0 0 0 1 1]
# Actual:  [0 0 0 0 0 1 1]
# Prediction: [1 1 1 0 1 1 1]
# Actual:  [1 1 1 0 0 0 0]
# Prediction: [0 0 0 1 0 0 0]
# Actual:  [1 1 0 1 1 1 0]
# Prediction: [0 0 0 1 0 0 0]
# Actual:  [0 1 1 1 0 1 0]
# Prediction: [0 0 0 0 0 0 1]
# Actual:  [0 1 1 0 0 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 0 0 0 1 1]
# Prediction: [1 0 0 0 0 0 0]
# Actual:  [1 1 1 0 0 0 0]
# Prediction: [0 1 0 0 0 0 0]
# Actual:  [1 1 0 1 1 1 0]
# Prediction: [1 1 0 0 0 0 0]
# Actual:  [0 1 1 1 0 1 0]
# Prediction: [0 0 1 0 0 0 1]
# Actual:  [0 1 1 0 0 0 1]
# Prediction: [0 1 0 0 0 0 1]
# Actual:  [0 0 0 0 0 1 1]
# Prediction: [0 0 0 1 0 0 0]
# Actual:  [1 1 1 0 0 0 0]
# Prediction: [1 0 0 1 0 0 0]
# Actual:  [1 1 0 1 1 1 0]
# Prediction: [0 0 1 1 1 0 0]
# Actual:  [0 1 1 1 0 1 0]
# Prediction: [0 0 0 0 1 0 1]
# Actual:  [0 1 1 0 0 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 0 0 0 1 1]
# Prediction: [1 0 0 0 1 0 1]
# Actual:  [1 1 1 0 0 0 0]
# Prediction: [1 0 0 0 0 1 0]
# Actual:  [1 1 0 1 1 1 0]
# Prediction: [0 1 1 1 0 0 0]
# Actual:  [0 1 1 1 0 1 0]
# Prediction: [1 1 0 0 0 0 0]
# Actual:  [0 1 1 0 0 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 0 0 0 1 1]
# Prediction: [1 0 1 0 0 0 0]
# Actual:  [1 1 1 0 0 0 0]
# Prediction: [1 1 0 0 0 0 0]
# Actual:  [1 1 0 1 1 1 0]
# Prediction: [0 0 1 0 0 0 1]
# Actual:  [0 1 1 1 0 1 0]
# SVC(C=1.0, cache_size=500, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.57142857  0.57142857  0.85714286  0.42857143  0.42857143]
# [ 0.14285714  0.71428571  0.57142857  0.42857143  0.57142857]
# [ 0.71428571  0.71428571  0.71428571  0.42857143  0.42857143]
# [ 0.85714286  0.71428571  0.42857143  0.57142857  0.57142857]
# [ 0.57142857  0.71428571  0.42857143  0.57142857  0.85714286]
# [ 0.57142857  0.71428571  0.85714286  0.57142857  0.42857143]
#
#
# Average Overall Score:   0.590476190476
# Prediction: [1 1 1 1 1 0 1]
# Actual:  [0 0 0 0 1 0 0]
# Prediction: [0 0 0 0 0 0 1]
# Actual:  [0 0 0 1 1 0 1]
# Prediction: [0 0 1 0 0 0 0]
# Actual:  [0 1 1 1 1 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 1 0 1 0 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 0 1 0 0 1 0]
# Prediction: [1 1 0 1 1 1 0]
# Actual:  [0 0 0 0 1 0 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 0 1 1 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 1 1 1 1 1 0]
# Prediction: [1 0 0 0 0 0 0]
# Actual:  [1 1 1 0 1 0 0]
# Prediction: [1 0 0 0 0 0 1]
# Actual:  [1 0 1 0 0 1 0]
# Prediction: [1 1 1 1 1 0 0]
# Actual:  [0 0 0 0 1 0 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 0 1 1 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 1 1 1 1 1 0]
# Prediction: [0 0 1 0 0 0 0]
# Actual:  [1 1 1 0 1 0 0]
# Prediction: [0 0 1 0 0 1 0]
# Actual:  [1 0 1 0 0 1 0]
# Prediction: [0 0 1 1 1 1 0]
# Actual:  [0 0 0 0 1 0 0]
# Prediction: [0 0 0 0 1 0 1]
# Actual:  [0 0 0 1 1 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 1 1 1 1 1 0]
# Prediction: [1 1 0 0 0 0 0]
# Actual:  [1 1 1 0 1 0 0]
# Prediction: [1 0 0 1 0 1 0]
# Actual:  [1 0 1 0 0 1 0]
# Prediction: [0 0 0 1 0 0 1]
# Actual:  [0 0 0 0 1 0 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 0 1 1 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 1 1 1 1 1 0]
# Prediction: [0 0 1 0 1 0 0]
# Actual:  [1 1 1 0 1 0 0]
# Prediction: [1 0 0 0 0 0 1]
# Actual:  [1 0 1 0 0 1 0]
# Prediction: [0 1 1 1 1 1 0]
# Actual:  [0 0 0 0 1 0 0]
# Prediction: [0 0 0 0 1 0 0]
# Actual:  [0 0 0 1 1 0 1]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 1 1 1 1 1 0]
# Prediction: [0 0 1 1 1 0 0]
# Actual:  [1 1 1 0 1 0 0]
# Prediction: [0 1 0 0 0 0 0]
# Actual:  [1 0 1 0 0 1 0]
# SVC(C=1.0, cache_size=500, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.28571429  0.71428571  0.42857143  0.42857143  0.57142857]
# [ 0.42857143  0.57142857  0.28571429  0.57142857  0.57142857]
# [ 0.42857143  0.57142857  0.28571429  0.57142857  0.85714286]
# [ 0.57142857  0.85714286  0.28571429  0.71428571  0.71428571]
# [ 0.57142857  0.57142857  0.28571429  0.71428571  0.57142857]
# [ 0.42857143  0.71428571  0.28571429  0.57142857  0.42857143]
#
#
# Average Overall Score:   0.528571428571
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 0 0 1 1 0]
# Prediction: [1 0 0 0 0 0 0]
# Actual:  [0 0 1 1 0 0 1]
# Prediction: [0 1 0 0 0 1 0]
# Actual:  [0 1 0 0 0 1 0]
# Prediction: [1 1 1 1 1 1 1]
# Actual:  [0 0 0 1 0 0 0]
# Prediction: [1 0 1 1 0 0 1]
# Actual:  [1 1 0 0 0 1 0]
# Prediction: [0 0 0 0 1 0 1]
# Actual:  [1 1 0 0 1 1 0]
# Prediction: [0 1 0 0 1 1 1]
# Actual:  [0 0 1 1 0 0 1]
# Prediction: [0 1 1 0 1 1 1]
# Actual:  [0 1 0 0 0 1 0]
# Prediction: [1 1 1 1 1 1 1]
# Actual:  [0 0 0 1 0 0 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 0 0 0 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 0 0 1 1 0]
# Prediction: [1 1 0 0 1 1 1]
# Actual:  [0 0 1 1 0 0 1]
# Prediction: [0 0 0 0 0 1 1]
# Actual:  [0 1 0 0 0 1 0]
# Prediction: [1 1 1 1 1 1 1]
# Actual:  [0 0 0 1 0 0 0]
# Prediction: [0 0 1 0 0 1 0]
# Actual:  [1 1 0 0 0 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 0 0 1 1 0]
# Prediction: [0 1 1 0 0 0 1]
# Actual:  [0 0 1 1 0 0 1]
# Prediction: [0 0 0 0 1 0 0]
# Actual:  [0 1 0 0 0 1 0]
# Prediction: [1 1 0 1 1 1 1]
# Actual:  [0 0 0 1 0 0 0]
# Prediction: [1 0 0 1 0 1 0]
# Actual:  [1 1 0 0 0 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 0 0 1 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 1 1 0 0 1]
# Prediction: [1 1 0 1 0 0 1]
# Actual:  [0 1 0 0 0 1 0]
# Prediction: [1 1 1 1 1 1 1]
# Actual:  [0 0 0 1 0 0 0]
# Prediction: [1 0 0 0 0 1 0]
# Actual:  [1 1 0 0 0 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [1 1 0 0 1 1 0]
# Prediction: [0 0 0 0 0 0 0]
# Actual:  [0 0 1 1 0 0 1]
# Prediction: [1 1 0 0 0 0 1]
# Actual:  [0 1 0 0 0 1 0]
# Prediction: [1 1 0 1 1 0 1]
# Actual:  [0 0 0 1 0 0 0]
# Prediction: [1 1 0 1 0 1 0]
# Actual:  [1 1 0 0 0 1 0]
# SVC(C=1.0, cache_size=500, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.42857143  0.42857143  1.          0.14285714  0.28571429]
# [ 0.42857143  0.28571429  0.57142857  0.14285714  0.57142857]
# [ 0.42857143  0.14285714  0.71428571  0.14285714  0.57142857]
# [ 0.42857143  0.71428571  0.57142857  0.28571429  0.71428571]
# [ 0.42857143  0.57142857  0.42857143  0.14285714  0.85714286]
# [ 0.42857143  0.57142857  0.57142857  0.42857143  0.85714286]
#
#
# Average Overall Score:   0.47619047619
