# %%
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../code/")
from svm_ann import main
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-4-3a0e665066e0> in <module>()
#       3 import sys
#       4 sys.path.insert(0, "../code/")
# ----> 5 from svm_ann import main
#
# ImportError: No module named svm_ann

# %%
for seed in [1,28,42]:
    predictions = main("../pickle_data/feature_dataframes/all_features_restructured.p", seed, False)
    sns.heatmap(predictions, annot=True)
    plt.title("Estimator accuracies per trait per task using random seed: {}".format(seed))
    plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-6520d9446ed4> in <module>()
#       1 for seed in [1,28,42]:
# ----> 2     predictions = main("../pickle_data/feature_dataframes/all_features_restructured.p", seed)
#       3     sns.heatmap(predictions, annot=True)
#       4     plt.title("Estimator accuracies per trait per task using random seed: {}".format(random_seed))
#       5     plt.show()
#
# NameError: name 'main' is not defined
