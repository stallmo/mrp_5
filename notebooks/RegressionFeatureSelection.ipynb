# %% [markdown]
# ### Without any selection (baseline)

# %%
import sys
sys.path.append('../code/')
import regression_per_task

# %%
path_to_pickle = '../pickle_data/feature_dataframes/all_features_per_task_w_sensor_norm.p'
test_size = 0.2

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         n_pca_var=None,
                         n_pca_cor=None,
                         variance_features=None)
# Out:
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.2642603  -0.36596797 -0.37890418 -0.05126543  0.00188709]
# [-0.13626429 -0.36764595 -0.2540314  -0.69052688  0.31072681]
# [-0.00094685 -0.36886474 -0.37234868 -0.54147559  0.00249365]
# [ 0.33722024 -0.3711619  -0.16786813 -0.54285449 -0.002874  ]
# [ 0.03833433 -0.38658897 -0.40191458 -0.53733189  0.24515391]
# [-0.00938845 -0.38032298 -0.40253584  0.03625932 -0.01375537]
#
#
#
# ['Rand_F' 'Gauss_P' 'Gauss_P' 'Rand_F' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'ANN' 'Gauss_P' 'ANN']
# ['Gauss_P' 'Gauss_P' 'Gauss_P' 'Gauss_P' 'Gauss_P']
# ['SVM' 'Gauss_P' 'ANN' 'Gauss_P' 'Gauss_P']
# ['Gauss_P' 'Bayes_R' 'Gauss_P' 'Bayes_R' 'ANN']
# ['Gauss_P' 'Gauss_P' 'Gauss_P' 'ANN' 'Gauss_P']

# %% [markdown]
# ### With PCA
# * after variance and correlation selection

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=10,
                         n_pca_cor=10,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.00503597 -0.30093956 -0.62423592 -0.35302932 -0.16414632]
# [ 0.01414696 -0.06452605 -0.89306306 -0.77325823  0.31038852]
# [-0.09468767 -1.         -1.         -1.         -0.0912445 ]
# [-0.18208005 -0.41168301 -0.1340252  -0.49563202  0.30724567]
# [-0.04803756 -1.         -0.30090992 -0.42218621 -0.11031147]
# [-0.28741453 -1.         -0.32632698 -0.28000771  0.13410798]
#
#
#
# ['Lin_Reg' 'Rand_F' 'Rand_F' 'Bayes_R' 'ANN']
# ['ANN' 'SVM' 'KNN' 'ANN' 'Gauss_P']
# ['Bayes_R' 'Nan' 'Nan' 'Nan' 'KNN']
# ['Rand_F' 'Rand_F' 'KNN' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Nan' 'ANN' 'Bayes_R' 'Bayes_R']
# ['KNN' 'Nan' 'Lin_Reg' 'SVM' 'Bayes_R']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=5,
                         n_pca_cor=5,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.0704447  -1.         -0.39899357 -0.25776689 -0.38048322]
# [-0.21231653 -0.36736202 -0.98716636 -1.         -0.04010091]
# [-0.02618408  0.16173238 -0.3977902  -0.50952855 -0.04571721]
# [-0.20878415 -0.61497738 -0.12138852 -0.61308394  0.05624309]
# [ 0.16827023 -0.44715491 -0.21034853 -0.39703875  0.60661314]
# [-0.10245447 -0.81719821 -0.18511743 -0.215132   -0.60046961]
#
#
#
# ['KNN' 'Nan' 'Rand_F' 'SVM' 'ANN']
# ['KNN' 'Bayes_R' 'KNN' 'Nan' 'Rand_F']
# ['KNN' 'SVM' 'KNN' 'ANN' 'ANN']
# ['Rand_F' 'KNN' 'KNN' 'Bayes_R' 'Rand_F']
# ['Lin_Reg' 'KNN' 'Rand_F' 'Bayes_R' 'Gauss_P']
# ['ANN' 'KNN' 'Lin_Reg' 'Lin_Reg' 'Rand_F']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=12,
                         n_pca_cor=12,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.15535174 -1.         -0.69504021 -0.36163683 -0.1110477 ]
# [-0.24530294 -0.23039369 -0.46011695 -1.          0.14230015]
# [-0.16289776 -1.         -0.47611897 -1.         -0.06499028]
# [-0.18965005 -0.09959506  0.0158634  -0.6436714   0.2989779 ]
# [ 0.0139684  -1.         -0.46004304 -0.56910576  0.08752348]
# [-0.20043711 -0.78610982  0.03031193 -0.39184908  0.01160942]
#
#
#
# ['Lin_Reg' 'Nan' 'Rand_F' 'KNN' 'KNN']
# ['ANN' 'Bayes_R' 'ANN' 'Nan' 'Rand_F']
# ['Bayes_R' 'Nan' 'KNN' 'Nan' 'ANN']
# ['Rand_F' 'KNN' 'KNN' 'Bayes_R' 'Rand_F']
# ['Bayes_R' 'Nan' 'ANN' 'Bayes_R' 'ANN']
# ['ANN' 'Rand_F' 'KNN' 'KNN' 'Bayes_R']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=1,
                         n_pca_cor=14,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [-0.0851686   0.14272481 -0.69291757 -0.43437758 -0.17727774]
# [-0.29489309 -0.17078323 -0.83783702 -0.79361111 -0.09343218]
# [ 0.12136517 -1.         -0.88347912 -1.         -0.16099982]
# [-0.0136389  -0.95012763  0.11418953 -0.53858025  0.25135166]
# [-0.1137839  -0.50588713 -0.58509124 -0.43399784  0.16820498]
# [ 0.24640732 -0.31802429 -0.0089741  -0.13953704  0.11900272]
#
#
#
# ['KNN' 'Gauss_P' 'KNN' 'Lin_Reg' 'KNN']
# ['ANN' 'Bayes_R' 'ANN' 'Rand_F' 'Rand_F']
# ['ANN' 'Nan' 'Bayes_R' 'Nan' 'KNN']
# ['ANN' 'Bayes_R' 'SVM' 'Rand_F' 'SVM']
# ['Bayes_R' 'KNN' 'KNN' 'Bayes_R' 'KNN']
# ['ANN' 'KNN' 'SVM' 'Rand_F' 'Bayes_R']

# %% [markdown]
# ### Only top n variance features

# %% [markdown]
# ##### n=10

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False, 
                         variance_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.29912049 -0.85646977 -0.96488504  0.31037645  0.12325008]
# [  1.68950747e-01  -3.68569328e-01  -3.56806857e-01  -9.74166141e-01
#    6.44257062e-04]
# [ 0.00890074 -0.36725031 -0.04562354 -0.58004494  0.26504115]
# [  2.70132057e-01  -3.53473310e-01  -3.78282633e-01  -4.02777778e-01
#   -9.97152494e-05]
# [ 0.31920088 -0.06006314 -0.32935799 -0.54045072  0.08745236]
# [-0.00397274  0.36407674 -0.10812279 -0.20831218  0.42452757]
#
#
#
# ['Lin_Reg' 'KNN' 'Bayes_R' 'SVM' 'Rand_F']
# ['ANN' 'Bayes_R' 'Bayes_R' 'Lin_Reg' 'Bayes_R']
# ['ANN' 'Bayes_R' 'ANN' 'Bayes_R' 'Rand_F']
# ['Lin_Reg' 'ANN' 'Bayes_R' 'Rand_F' 'Bayes_R']
# ['Lin_Reg' 'KNN' 'ANN' 'Bayes_R' 'Rand_F']
# ['Bayes_R' 'KNN' 'Rand_F' 'SVM' 'Rand_F']

# %% [markdown]
# #### n=5

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False, 
                         variance_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.07365399 -0.77252831 -0.56500215  0.37551125 -0.00114293]
# [ 0.19744751 -0.25291855 -0.37722046 -1.          0.15996223]
# [ 0.01307457 -0.36844126 -0.36474268 -0.56049118 -0.0037177 ]
# [  7.36619971e-02   1.91996791e-01  -1.87913602e-01  -5.25462963e-01
#   -4.32540906e-04]
# [-0.00166121  0.18308779 -0.01990744  0.00956674  0.14142237]
# [ 0.07712005 -0.0389392  -0.42639304 -0.22552469  0.35324429]
#
#
#
# ['Lin_Reg' 'KNN' 'Bayes_R' 'SVM' 'Bayes_R']
# ['ANN' 'KNN' 'Bayes_R' 'Nan' 'Rand_F']
# ['Lin_Reg' 'Bayes_R' 'KNN' 'Bayes_R' 'Bayes_R']
# ['KNN' 'Rand_F' 'Lin_Reg' 'Rand_F' 'Bayes_R']
# ['Bayes_R' 'KNN' 'ANN' 'ANN' 'Rand_F']
# ['Lin_Reg' 'Rand_F' 'Bayes_R' 'Rand_F' 'SVM']

# %% [markdown]
# ### Only features with n highest correlation

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.11647628 -0.26140325 -0.48805992 -0.16960551  0.34114237]
# [-0.69769717 -0.18190932 -0.88377442 -0.41006173  0.1864194 ]
# [-0.01582062 -0.10860438 -0.94647852 -0.5427075   0.35342511]
# [  2.05773921e-01  -3.68292428e-01  -3.30376960e-01  -1.79207931e-01
#   -2.79499245e-05]
# [ 0.08361047  0.07016139 -0.37915365 -0.45722517  0.24159318]
# [-0.19413086 -0.3348201  -0.37819675 -0.33674519 -0.00393727]
#
#
#
# ['Rand_F' 'KNN' 'Bayes_R' 'Lin_Reg' 'ANN']
# ['KNN' 'KNN' 'ANN' 'Rand_F' 'KNN']
# ['Rand_F' 'Lin_Reg' 'KNN' 'Bayes_R' 'Lin_Reg']
# ['Rand_F' 'Bayes_R' 'Bayes_R' 'Lin_Reg' 'Bayes_R']
# ['Bayes_R' 'SVM' 'Bayes_R' 'ANN' 'Lin_Reg']
# ['KNN' 'SVM' 'Bayes_R' 'Lin_Reg' 'Bayes_R']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.51520163  0.12220895 -0.61824837 -0.5418614   0.28071016]
# [-0.52360653 -0.2654066  -0.40229367 -0.54079899 -0.00156041]
# [ 0.1662834  -0.3695886  -0.87654155 -0.54018754  0.18654471]
# [-0.1810523  -0.2553115  -0.18420936 -0.04134034  0.08385991]
# [ 0.01513883  0.10989552 -0.3788503  -0.25791621  0.26123415]
# [-0.10643191 -0.1865669  -0.37700834 -0.29114895 -0.11218082]
#
#
#
# ['Rand_F' 'Rand_F' 'Bayes_R' 'Bayes_R' 'Lin_Reg']
# ['Rand_F' 'KNN' 'Lin_Reg' 'Bayes_R' 'Bayes_R']
# ['KNN' 'Bayes_R' 'Rand_F' 'Bayes_R' 'Rand_F']
# ['KNN' 'SVM' 'KNN' 'Lin_Reg' 'ANN']
# ['Bayes_R' 'SVM' 'Bayes_R' 'ANN' 'Lin_Reg']
# ['KNN' 'KNN' 'Bayes_R' 'SVM' 'Bayes_R']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=7)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.11858896 -0.36899755 -0.48502815 -0.5417012   0.30998869]
# [ -4.00016644e-01  -3.55387779e-01  -9.23864137e-01   1.40679012e-01
#    6.29071050e-05]
# [ -2.05231978e-04  -1.21863689e-01  -8.87657030e-01  -5.23610461e-01
#    1.94889503e-01]
# [ -6.06133137e-02  -2.31675435e-01  -3.87725247e-01   4.37432268e-01
#   -1.72815621e-04]
# [ 0.06458366  0.26994574 -0.37918062 -0.37685786  0.42169796]
# [-0.05698714 -0.25653325 -0.37771644 -0.10805556 -0.02844378]
#
#
#
# ['KNN' 'Bayes_R' 'KNN' 'Bayes_R' 'SVM']
# ['KNN' 'KNN' 'KNN' 'Rand_F' 'Bayes_R']
# ['KNN' 'KNN' 'KNN' 'KNN' 'Rand_F']
# ['Rand_F' 'SVM' 'Bayes_R' 'SVM' 'Bayes_R']
# ['Bayes_R' 'SVM' 'Bayes_R' 'ANN' 'Lin_Reg']
# ['KNN' 'SVM' 'Bayes_R' 'Rand_F' 'Bayes_R']

# %% [markdown]
# ### Variance based and correlation based feature selection without PCA

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 10,
                         correlation_features=10)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.59700735 -0.97234565 -0.57448621 -0.02871252 -0.00662619]
# [-0.68613078 -0.36813864 -0.47858708 -0.94566173  0.16174845]
# [ 0.12320039 -0.36695775 -0.15750223 -0.81370682  0.24171263]
# [-0.12453482 -0.15297871 -0.37822837 -0.53279389  0.08124309]
# [ 0.20021396 -0.37807279 -0.2543249  -0.33166667  0.04802155]
# [-0.05388605 -0.24606556 -0.43998808 -0.05742232  0.37690608]
#
#
#
# ['Lin_Reg' 'KNN' 'Lin_Reg' 'SVM' 'Bayes_R']
# ['KNN' 'Bayes_R' 'ANN' 'Lin_Reg' 'Gauss_P']
# ['Lin_Reg' 'Bayes_R' 'ANN' 'Bayes_R' 'ANN']
# ['Rand_F' 'SVM' 'Bayes_R' 'Bayes_R' 'Rand_F']
# ['Bayes_R' 'Bayes_R' 'ANN' 'Rand_F' 'Lin_Reg']
# ['KNN' 'SVM' 'Bayes_R' 'SVM' 'Rand_F']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 5,
                         correlation_features=5)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.32329221 -0.34988379 -0.67927093 -0.47033405 -0.00168431]
# [-0.57026553 -0.22548859 -0.44715657 -1.          0.07359413]
# [ 0.0334205  -0.3683579  -0.1670589  -0.60468083  0.0022044 ]
# [-0.24266248  0.19199679 -0.1187889  -0.39654819  0.00254656]
# [ 0.06757634 -0.38612537  0.23509777 -0.29095038  0.04802155]
# [-0.20032268 -0.21252346 -0.51111001 -0.39887456 -0.00574934]
#
#
#
# ['Lin_Reg' 'KNN' 'Bayes_R' 'SVM' 'Bayes_R']
# ['Bayes_R' 'SVM' 'Bayes_R' 'Nan' 'KNN']
# ['KNN' 'Bayes_R' 'KNN' 'Bayes_R' 'SVM']
# ['Bayes_R' 'Rand_F' 'Lin_Reg' 'KNN' 'ANN']
# ['Bayes_R' 'Bayes_R' 'ANN' 'ANN' 'Lin_Reg']
# ['KNN' 'SVM' 'Bayes_R' 'Lin_Reg' 'KNN']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 3,
                         correlation_features=4)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.23677111 -0.31190028 -0.34953543 -0.22533951  0.0246881 ]
# [-0.54701849 -0.36856778 -0.51027218 -1.          0.05301105]
# [ 0.03125243  0.16988051 -0.35804002 -0.22530864  0.00376293]
# [-0.24043657  0.03430606 -0.32932336 -0.39382162 -0.0004149 ]
# [-0.0131385  -0.36111373  0.42939959 -0.46093471 -0.02383984]
# [-0.06790322  0.04721352 -0.44670241 -0.31808642 -0.0446089 ]
#
#
#
# ['SVM' 'KNN' 'ANN' 'Rand_F' 'SVM']
# ['KNN' 'Bayes_R' 'Bayes_R' 'Nan' 'SVM']
# ['KNN' 'SVM' 'KNN' 'Rand_F' 'KNN']
# ['KNN' 'SVM' 'Lin_Reg' 'KNN' 'Bayes_R']
# ['Bayes_R' 'KNN' 'ANN' 'Lin_Reg' 'Bayes_R']
# ['KNN' 'KNN' 'Rand_F' 'Rand_F' 'KNN']

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 12,
                         correlation_features=12)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.51283214 -1.         -0.57989122  0.15829339 -0.00794522]
# [-0.52102883 -0.36847174 -0.62480599 -0.94566173  0.21242689]
# [-0.20850961 -0.1282957  -0.18667481 -0.81959533  0.35512718]
# [ 0.06839677 -0.16720727 -0.21070343 -0.48070988 -0.00080275]
# [ 0.10022252 -0.25236012  0.01587271 -0.26078056  0.0793218 ]
# [-0.197366   -0.03578494  0.02800322 -0.04481324  0.1718232 ]
#
#
#
# ['ANN' 'Nan' 'Lin_Reg' 'SVM' 'Bayes_R']
# ['KNN' 'Bayes_R' 'ANN' 'Lin_Reg' 'Gauss_P']
# ['ANN' 'KNN' 'ANN' 'Bayes_R' 'ANN']
# ['KNN' 'SVM' 'KNN' 'Rand_F' 'Bayes_R']
# ['Bayes_R' 'KNN' 'ANN' 'ANN' 'KNN']
# ['Rand_F' 'SVM' 'Rand_F' 'SVM' 'Rand_F']
