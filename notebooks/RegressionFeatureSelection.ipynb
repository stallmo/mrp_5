# %% [markdown]
# ### Without any selection (baseline)

# %%
import sys
sys.path.append('../code/')
import regression_per_task

# %%
path_to_pickle = '../pickle_data/feature_dataframes/all_features_per_task_w_sensor_norm.p'
test_size = 0.2

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         n_pca_var=None,
                         n_pca_cor=None,
                         variance_features=None)
# Out:
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.2642603  -0.36596797 -0.37890418 -0.05126543  0.00188709]
# [-0.13626429 -0.36764595 -0.13745104 -0.69052688  0.33594674]
# [ 0.02255709 -0.36886474 -0.37234868 -0.54147559  0.1343752 ]
# [ 0.33722024 -0.3711619  -0.16566257 -0.54285449 -0.002874  ]
# [ 0.36335359 -0.38658897 -0.40191458 -0.45323022  0.16033136]
# [-0.00938845  0.15743968 -0.40253584 -0.38932377 -0.01375537]
#
#
#
# ['KNN' 'Gauss_P' 'Gauss_P' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'ANN' 'Gauss_P' 'Ada_B']
# ['Ada_B' 'Gauss_P' 'Gauss_P' 'Gauss_P' 'Ada_B']
# ['SVM' 'Gauss_P' 'Ada_B' 'Gauss_P' 'Gauss_P']
# ['ANN' 'Bayes_R' 'Gauss_P' 'Ada_B' 'Ada_B']
# ['Gauss_P' 'Ada_B' 'Gauss_P' 'Ada_B' 'Gauss_P']
# {'task0': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait1': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait2': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}},
#  'task1': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed',
#     'a50_activations_over_total',
#     'a50_time_over_total',
# ...
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}}}

# %% [markdown]
# ### With PCA
# * after variance and correlation selection

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=10,
                         n_pca_cor=10,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.2642603  -0.36596797 -0.37890418 -0.05126543  0.00188709]
# [-0.13626429 -0.36764595 -0.38072958 -0.69052688  0.22966754]
# [-0.00094685 -0.36886474 -0.37234868 -0.54147559  0.00249365]
# [ 0.33722024 -0.3711619  -0.07285191 -0.54285449 -0.002874  ]
# [ 0.03833433 -0.38658897 -0.40191458 -0.28909737  0.13929659]
# [-0.00938845  0.50819536 -0.40253584  0.06869599  0.03283653]
#
#
#
# ['KNN' 'Gauss_P' 'Gauss_P' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'Gauss_P' 'Bayes_R']
# ['Gauss_P' 'Gauss_P' 'Gauss_P' 'Gauss_P' 'Gauss_P']
# ['SVM' 'Gauss_P' 'Ada_B' 'Gauss_P' 'Gauss_P']
# ['Gauss_P' 'Bayes_R' 'Gauss_P' 'Ada_B' 'Ada_B']
# ['Gauss_P' 'Ada_B' 'Gauss_P' 'Ada_B' 'Ada_B']
# {'task0': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait1': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait2': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}},
#  'task1': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed',
#     'a50_activations_over_total',
#     'a50_time_over_total',
#     'a51_activations_over_total',
#     'a51_time_over_total',
#     'a56_activations_over_total',
#     'a56_time_over_total',
#     'max_time_a50',
#     'max_time_a51',
#     'max_time_a56',
#     'mean_time_a50',
#     'mean_time_a51',
#     'mean_time_a56',
#     'min_time_a50',
# ...
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)}}}

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=5,
                         n_pca_cor=5,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.2642603  -0.36596797 -0.37890418 -0.05126543  0.00188709]
# [-0.13626429 -0.36764595 -0.11489927 -0.69052688  0.22966754]
# [ 0.18842266 -0.36886474 -0.37234868 -0.54147559  0.00249365]
# [ 0.33722024 -0.3711619  -0.23450813 -0.54285449  0.01305587]
# [ 0.03833433 -0.38658897 -0.40191458 -0.53733189  0.25899548]
# [-0.00938845 -0.38032298 -0.40253584  0.1875     -0.01375537]
#
#
#
# ['KNN' 'Gauss_P' 'Gauss_P' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'Ada_B' 'Gauss_P' 'Bayes_R']
# ['Ada_B' 'Gauss_P' 'Gauss_P' 'Gauss_P' 'Gauss_P']
# ['SVM' 'Gauss_P' 'SVM' 'Gauss_P' 'Ada_B']
# ['Gauss_P' 'Bayes_R' 'Gauss_P' 'Bayes_R' 'Ada_B']
# ['Gauss_P' 'Gauss_P' 'Gauss_P' 'Ada_B' 'Gauss_P']
# {'task0': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait1': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait2': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}},
#  'task1': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed',
#     'a50_activations_over_total',
#     'a50_time_over_total',
#     'a51_activations_over_total',
#     'a51_time_over_total',
#     'a56_activations_over_total',
#     'a56_time_over_total',
#     'max_time_a50',
#     'max_time_a51',
#     'max_time_a56',
#     'mean_time_a50',
#     'mean_time_a51',
#     'mean_time_a56',
#     'min_time_a50',
# ...
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}}}

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=12,
                         n_pca_cor=12,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.2642603  -0.36596797 -0.37890418 -0.05126543  0.00188709]
# [-0.13626429 -0.36764595 -0.36582372 -0.69052688  0.24773401]
# [-0.00094685 -0.36886474 -0.27310135 -0.54147559  0.00249365]
# [ 0.33722024 -0.3711619  -0.23450813 -0.54285449 -0.002874  ]
# [ 0.03833433 -0.38658897 -0.40191458 -0.53733189  0.14689486]
# [-0.00938845 -0.38032298 -0.40253584 -0.02220679 -0.01375537]
#
#
#
# ['KNN' 'Gauss_P' 'Gauss_P' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'Ada_B' 'Gauss_P' 'Ada_B']
# ['Gauss_P' 'Gauss_P' 'Ada_B' 'Gauss_P' 'Gauss_P']
# ['SVM' 'Gauss_P' 'SVM' 'Gauss_P' 'Gauss_P']
# ['Gauss_P' 'Bayes_R' 'Gauss_P' 'Bayes_R' 'Ada_B']
# ['Gauss_P' 'Gauss_P' 'Gauss_P' 'Ada_B' 'Gauss_P']
# {'task0': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait1': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait2': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}},
#  'task1': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed',
#     'a50_activations_over_total',
#     'a50_time_over_total',
#     'a51_activations_over_total',
#     'a51_time_over_total',
#     'a56_activations_over_total',
#     'a56_time_over_total',
#     'max_time_a50',
#     'max_time_a51',
#     'max_time_a56',
#     'mean_time_a50',
#     'mean_time_a51',
#     'mean_time_a56',
#     'min_time_a50',
# ...
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}}}

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size=test_size,
                         print_extended=False,
                         pca=True,
                         n_pca_var=1,
                         n_pca_cor=14,
                         variance_features = None)
# Out:
# ['extraversion', 'agreeableness', 'conscientiousness', 'neuroticism', 'openness_to_experience']
# [ 0.2642603  -0.36596797 -0.37890418 -0.05126543  0.00188709]
# [-0.13626429 -0.36764595 -0.38072958 -0.69052688  0.37322014]
# [-0.00094685 -0.36886474 -0.33922473 -0.54147559  0.27321214]
# [ 0.33722024 -0.3711619  -0.23450813 -0.54285449 -0.002874  ]
# [ 0.03833433 -0.38658897 -0.40191458 -0.53733189  0.04350829]
# [-0.00938845 -0.08659899 -0.3917285  -0.14013676  0.25652818]
#
#
#
# ['KNN' 'Gauss_P' 'Gauss_P' 'KNN' 'Gauss_P']
# ['Bayes_R' 'Bayes_R' 'Bayes_R' 'Gauss_P' 'Ada_B']
# ['Gauss_P' 'Gauss_P' 'Ada_B' 'Gauss_P' 'Ada_B']
# ['SVM' 'Gauss_P' 'SVM' 'Gauss_P' 'Gauss_P']
# ['Gauss_P' 'Bayes_R' 'Gauss_P' 'Bayes_R' 'KNN']
# ['Gauss_P' 'Ada_B' 'ANN' 'Ada_B' 'Ada_B']
# {'task0': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait1': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait2': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#              metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#              weights='uniform')},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': GaussianProcessRegressor(alpha=1e-10, copy_X_train=True, kernel=None,
#                 n_restarts_optimizer=0, normalize_y=True,
#                 optimizer='fmin_l_bfgs_b', random_state=None)}},
#  'task1': {'trait0': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed',
#     'a50_activations_over_total',
#     'a50_time_over_total',
#     'a51_activations_over_total',
#     'a51_time_over_total',
#     'a56_activations_over_total',
#     'a56_time_over_total',
#     'max_time_a50',
#     'max_time_a51',
#     'max_time_a56',
#     'mean_time_a50',
#     'mean_time_a51',
#     'mean_time_a56',
#     'min_time_a50',
# ...
#           beta_2=0.999, early_stopping=False, epsilon=1e-08,
#           hidden_layer_sizes=(100,), learning_rate='adaptive',
#           learning_rate_init=0.001, max_iter=200, momentum=0.9,
#           nesterovs_momentum=True, power_t=0.5, random_state=None,
#           shuffle=True, solver='sgd', tol=0.0001, validation_fraction=0.1,
#           verbose=False, warm_start=False)},
#   'trait3': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)},
#   'trait4': {'feature_columns': ['elbowL_x-elbowR_x',
#     'elbowL_x-handL_x',
#     'elbowL_y-handL_y',
#     'elbowL_z-elbowR_z',
#     'elbowL_z-handL_z',
#     'elbowL_z-wristL_z',
#     'elbowR_x-handL_x',
#     'elbowR_y-elbowL_y',
#     'elbowR_y-handL_y',
#     'elbowR_z-handL_z',
#     'handR_x-elbowL_x',
#     'handR_x-elbowR_x',
#     'handR_x-handL_x',
#     'handR_x-neck_x',
#     'handR_x-shoulderL_x',
#     'handR_x-wristL_x',
#     'handR_x-wristR_x',
#     'handR_y-elbowL_y',
#     'handR_y-elbowR_y',
#     'handR_y-handL_y',
#     'handR_y-neck_y',
#     'handR_y-shoulderL_y',
#     'handR_y-wristL_y',
#     'handR_y-wristR_y',
#     'handR_z-elbowL_z',
#     'handR_z-elbowR_z',
#     'handR_z-handL_z',
#     'handR_z-neck_z',
#     'handR_z-shoulderL_z',
#     'handR_z-wristL_z',
#     'handR_z-wristR_z',
#     'head_x-elbowL_x',
#     'head_x-elbowR_x',
#     'head_x-handL_x',
#     'head_x-handR_x',
#     'head_x-neck_x',
#     'head_x-shoulderL_x',
#     'head_x-spineShoulder_x',
#     'head_x-wristL_x',
#     'head_x-wristR_x',
#     'head_y-elbowL_y',
#     'head_y-elbowR_y',
#     'head_y-handL_y',
#     'head_y-handR_y',
#     'head_y-neck_y',
#     'head_y-shoulderL_y',
#     'head_y-spineShoulder_y',
#     'head_y-wristL_y',
#     'head_y-wristR_y',
#     'head_z-elbowL_z',
#     'head_z-elbowR_z',
#     'head_z-handL_z',
#     'head_z-handR_z',
#     'head_z-neck_z',
#     'head_z-shoulderL_z',
#     'head_z-spineShoulder_z',
#     'head_z-wristL_z',
#     'head_z-wristR_z',
#     'neck_x-elbowL_x',
#     'neck_x-elbowR_x',
#     'neck_x-handL_x',
#     'neck_x-wristL_x',
#     'neck_y-elbowL_y',
#     'neck_y-elbowR_y',
#     'neck_y-handL_y',
#     'neck_y-wristL_y',
#     'neck_z-elbowL_z',
#     'neck_z-elbowR_z',
#     'neck_z-handL_z',
#     'neck_z-wristL_z',
#     'shoulderL_x-elbowL_x',
#     'shoulderL_x-elbowR_x',
#     'shoulderL_x-handL_x',
#     'shoulderL_x-neck_x',
#     'shoulderL_x-wristL_x',
#     'shoulderL_x-wristR_x',
#     'shoulderL_y-elbowL_y',
#     'shoulderL_y-elbowR_y',
#     'shoulderL_y-handL_y',
#     'shoulderL_y-neck_y',
#     'shoulderL_y-wristL_y',
#     'shoulderL_y-wristR_y',
#     'shoulderL_z-elbowL_z',
#     'shoulderL_z-elbowR_z',
#     'shoulderL_z-handL_z',
#     'shoulderL_z-neck_z',
#     'shoulderL_z-wristL_z',
#     'shoulderL_z-wristR_z',
#     'shoulderR_x-elbowL_x',
#     'shoulderR_x-elbowR_x',
#     'shoulderR_x-handL_x',
#     'shoulderR_x-handR_x',
#     'shoulderR_x-head_x',
#     'shoulderR_x-neck_x',
#     'shoulderR_x-shoulderL_x',
#     'shoulderR_x-spineShoulder_x',
#     'shoulderR_x-wristL_x',
#     'shoulderR_x-wristR_x',
#     'shoulderR_y-elbowL_y',
#     'shoulderR_y-elbowR_y',
#     'shoulderR_y-handL_y',
#     'shoulderR_y-handR_y',
#     'shoulderR_y-head_y',
#     'shoulderR_y-neck_y',
#     'shoulderR_y-shoulderL_y',
#     'shoulderR_y-spineShoulder_y',
#     'shoulderR_y-wristL_y',
#     'shoulderR_y-wristR_y',
#     'shoulderR_z-elbowL_z',
#     'shoulderR_z-elbowR_z',
#     'shoulderR_z-handL_z',
#     'shoulderR_z-handR_z',
#     'shoulderR_z-head_z',
#     'shoulderR_z-neck_z',
#     'shoulderR_z-shoulderL_z',
#     'shoulderR_z-spineShoulder_z',
#     'shoulderR_z-wristL_z',
#     'shoulderR_z-wristR_z',
#     'spineShoulder_x-elbowL_x',
#     'spineShoulder_x-elbowR_x',
#     'spineShoulder_x-handL_x',
#     'spineShoulder_x-handR_x',
#     'spineShoulder_x-neck_x',
#     'spineShoulder_x-shoulderL_x',
#     'spineShoulder_x-wristL_x',
#     'spineShoulder_x-wristR_x',
#     'spineShoulder_y-elbowL_y',
#     'spineShoulder_y-elbowR_y',
#     'spineShoulder_y-handL_y',
#     'spineShoulder_y-handR_y',
#     'spineShoulder_y-neck_y',
#     'spineShoulder_y-shoulderL_y',
#     'spineShoulder_y-wristL_y',
#     'spineShoulder_y-wristR_y',
#     'spineShoulder_z-elbowL_z',
#     'spineShoulder_z-elbowR_z',
#     'spineShoulder_z-handL_z',
#     'spineShoulder_z-handR_z',
#     'spineShoulder_z-neck_z',
#     'spineShoulder_z-shoulderL_z',
#     'spineShoulder_z-wristL_z',
#     'spineShoulder_z-wristR_z',
#     'wristL_x-elbowL_x',
#     'wristL_x-elbowR_x',
#     'wristL_x-handL_x',
#     'wristL_y-elbowL_y',
#     'wristL_y-elbowR_y',
#     'wristL_y-handL_y',
#     'wristL_z-elbowR_z',
#     'wristL_z-handL_z',
#     'wristR_x-elbowL_x',
#     'wristR_x-elbowR_x',
#     'wristR_x-handL_x',
#     'wristR_x-neck_x',
#     'wristR_x-wristL_x',
#     'wristR_y-elbowL_y',
#     'wristR_y-elbowR_y',
#     'wristR_y-handL_y',
#     'wristR_y-neck_y',
#     'wristR_y-wristL_y',
#     'wristR_z-elbowL_z',
#     'wristR_z-elbowR_z',
#     'wristR_z-handL_z',
#     'wristR_z-neck_z',
#     'wristR_z-wristL_z',
#     'ampl_freq_spineMid_x-handR_x',
#     'ampl_freq_spineMid_y-handR_y',
#     'ampl_freq_spineMid_z-handR_z',
#     'ampl_max_spineMid_x-handR_x',
#     'ampl_max_spineMid_y-handR_y',
#     'ampl_max_spineMid_z-handR_z',
#     'ampl_min_spineMid_x-handR_x',
#     'ampl_min_spineMid_y-handR_y',
#     'ampl_min_spineMid_z-handR_z',
#     'ampl_mean_spineMid_x-handR_x',
#     'ampl_mean_spineMid_y-handR_y',
#     'ampl_mean_spineMid_z-handR_z',
#     'ampl_freq_spineMid_x-handL_x',
#     'ampl_freq_spineMid_y-handL_y',
#     'ampl_freq_spineMid_z-handL_z',
#     'ampl_max_spineMid_x-handL_x',
#     'ampl_max_spineMid_y-handL_y',
#     'ampl_max_spineMid_z-handL_z',
#     'ampl_min_spineMid_x-handL_x',
#     'ampl_min_spineMid_y-handL_y',
#     'ampl_min_spineMid_z-handL_z',
#     'ampl_mean_spineMid_x-handL_x',
#     'ampl_mean_spineMid_y-handL_y',
#     'ampl_mean_spineMid_z-handL_z',
#     'ampl_freq_spineMid_x-wristL_x',
#     'ampl_freq_spineMid_y-wristL_y',
#     'ampl_freq_spineMid_z-wristL_z',
#     'ampl_max_spineMid_x-wristL_x',
#     'ampl_max_spineMid_y-wristL_y',
#     'ampl_max_spineMid_z-wristL_z',
#     'ampl_min_spineMid_x-wristL_x',
#     'ampl_min_spineMid_y-wristL_y',
#     'ampl_min_spineMid_z-wristL_z',
#     'ampl_mean_spineMid_x-wristL_x',
#     'ampl_mean_spineMid_y-wristL_y',
#     'ampl_mean_spineMid_z-wristL_z',
#     'ampl_freq_spineMid_x-head_x',
#     'ampl_freq_spineMid_y-head_y',
#     'ampl_freq_spineMid_z-head_z',
#     'ampl_max_spineMid_x-head_x',
#     'ampl_max_spineMid_y-head_y',
#     'ampl_max_spineMid_z-head_z',
#     'ampl_min_spineMid_x-head_x',
#     'ampl_min_spineMid_y-head_y',
#     'ampl_min_spineMid_z-head_z',
#     'ampl_mean_spineMid_x-head_x',
#     'ampl_mean_spineMid_y-head_y',
#     'ampl_mean_spineMid_z-head_z',
#     'ampl_freq_neck_x-handR_x',
#     'ampl_freq_neck_y-handR_y',
#     'ampl_freq_neck_z-handR_z',
#     'ampl_max_neck_x-handR_x',
#     'ampl_max_neck_y-handR_y',
#     'ampl_max_neck_z-handR_z',
#     'ampl_min_neck_x-handR_x',
#     'ampl_min_neck_y-handR_y',
#     'ampl_min_neck_z-handR_z',
#     'ampl_mean_neck_x-handR_x',
#     'ampl_mean_neck_y-handR_y',
#     'ampl_mean_neck_z-handR_z',
#     'ampl_freq_neck_x-handL_x',
#     'ampl_freq_neck_y-handL_y',
#     'ampl_freq_neck_z-handL_z',
#     'ampl_max_neck_x-handL_x',
#     'ampl_max_neck_y-handL_y',
#     'ampl_max_neck_z-handL_z',
#     'ampl_min_neck_x-handL_x',
#     'ampl_min_neck_y-handL_y',
#     'ampl_min_neck_z-handL_z',
#     'ampl_mean_neck_x-handL_x',
#     'ampl_mean_neck_y-handL_y',
#     'ampl_mean_neck_z-handL_z',
#     'ampl_freq_neck_x-wristL_x',
#     'ampl_freq_neck_y-wristL_y',
#     'ampl_freq_neck_z-wristL_z',
#     'ampl_max_neck_x-wristL_x',
#     'ampl_max_neck_y-wristL_y',
#     'ampl_max_neck_z-wristL_z',
#     'ampl_min_neck_x-wristL_x',
#     'ampl_min_neck_y-wristL_y',
#     'ampl_min_neck_z-wristL_z',
#     'ampl_mean_neck_x-wristL_x',
#     'ampl_mean_neck_y-wristL_y',
#     'ampl_mean_neck_z-wristL_z',
#     'ampl_freq_neck_x-head_x',
#     'ampl_freq_neck_y-head_y',
#     'ampl_freq_neck_z-head_z',
#     'ampl_max_neck_x-head_x',
#     'ampl_max_neck_y-head_y',
#     'ampl_max_neck_z-head_z',
#     'ampl_min_neck_x-head_x',
#     'ampl_min_neck_y-head_y',
#     'ampl_min_neck_z-head_z',
#     'ampl_mean_neck_x-head_x',
#     'ampl_mean_neck_y-head_y',
#     'ampl_mean_neck_z-head_z',
#     'max_speed',
#     'mean_speed',
#     'median_speed',
#     'min_speed'],
#    'model': AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#             n_estimators=50, random_state=None)}}}

# %% [markdown]
# ### Only top n variance features

# %% [markdown]
# ##### n=10

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False, 
                         variance_features=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7bd5a1a538f7> in <module>()
#       3                          print_extended=False,
#       4                          pca=False,
# ----> 5                          variance_features=10)
#
# /home/morris/MaastrichtUniversity/2017_period1/ResearchProject/git/mrp_5/code/regression_per_task.pyc in main(path_to_pickle, test_size, print_extended, pca, n_pca_var, n_pca_cor, variance_features, correlation_features)
#     137
#     138                     #print(potential_features)
# --> 139                     model.fit(X_train[potential_features], y_train)
#     140                     prediction = model.predict(X_test[potential_features])
#     141                     score = model.score(X_test[potential_features], y_test)
#
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /home/morris/anaconda3/envs/mrp/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     468                              " a minimum of %d is required%s."
#     469                              % (n_features, shape_repr, ensure_min_features,
# --> 470                                 context))
#     471
#     472     if warn_on_dtype and dtype_orig is not None and array.dtype != dtype_orig:
#
# ValueError: Found array with 0 feature(s) (shape=(35, 0)) while a minimum of 1 is required.

# %% [markdown]
# #### n=5

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False, 
                         variance_features=5)

# %% [markdown]
# ### Only features with n highest correlation

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=10)

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=5)

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = None,
                         correlation_features=7)

# %% [markdown]
# ### Variance based and correlation based feature selection without PCA

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 10,
                         correlation_features=10)

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 5,
                         correlation_features=5)

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 3,
                         correlation_features=4)

# %%
regression_per_task.main(path_to_pickle=path_to_pickle,
                         test_size = test_size,
                         print_extended=False,
                         pca=False,
                         variance_features = 12,
                         correlation_features=12)
